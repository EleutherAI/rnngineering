# %%
import mamba_ssm
from nnsight import LanguageModel, util
from nnsight.tracing.Proxy import Proxy
from nnsight.models.Mamba import MambaInterp
from transformers import AutoTokenizer
import numpy as np
import torch as t
import torch.nn.functional as F
import einops
from tqdm import tqdm
from functools import partial

from rich import print as rprint
from rich.table import Table

from typing import List, Callable, Union

device = t.device("cuda:2" if t.cuda.is_available() else "cpu")
# Out:
# /mnt/ssd-1/gpaulo/miniconda3/lib/python3.11/site-packages/diffusers/utils/outputs.py:63: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(

# %%
tokenizer = AutoTokenizer.from_pretrained("EleutherAI/gpt-neox-20b", padding_side="left")
tokenizer.pad_token_id = tokenizer.eos_token_id
mamba_model = MambaInterp("state-spaces/mamba-2.8b", device=device, tokenizer=tokenizer)
sampling_kwargs = {
    "top_p": 0.2,
    "top_k": 0,
    "repetition_penalty": 1.1,
} # in mamba_ssm/utils/generation.py
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
with mamba_model.generate(max_length=40,**sampling_kwargs,validate=False) as generator:
            
    with generator.invoke("Where is the Eiffel tower located at?",scan=True) as invoker:
        a = mamba_model.backbone.layers[0].mixer.ssm.hx.ah.output.save()
        y =  mamba_model.backbone.layers[12].mixer.ssm.yh.output.save()
        mamba_model.backbone.layers[12].mixer.ssm.yh.next()
        y2= mamba_model.backbone.layers[12].mixer.ssm.yh.output.save()
        
        pass
# Out:
# You're using a GPTNeoXTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.

# %%
print(y.value)
print(y2.value)
# Out:
# tensor([[-0.0081, -0.0081,  0.0015,  ..., -0.0085, -0.0005,  0.0026]],
#        device='cuda:2')
# tensor([[-0.0063, -0.0069,  0.0008,  ..., -0.0076, -0.0011,  0.0057]],
#        device='cuda:2')

# %%
# Out:
# ["Where is the Eiffel tower located at?\nWhat's a good way to get there from my hotel in Paris, France?\nHow do I find out more about this place on Google Maps"]

# %%
def print_table(completions, titles):
    table = Table("Type:","Completion 1", "Competion 2","Competion 3", title=f"Completions for steering at different layers and coefficients", show_lines=True)
    for i in range(len(titles)):
        
        table.add_row(titles[i], completions[i][0],completions[i][1],completions[i][2])
    rprint(table)

# %%
def apply_steering_vector(
    model: LanguageModel,
    steering_info:List[tuple],
    new_token_length: int,
    steering_prompt: List[str],
    prompts: List[str],
):
    unsteered_completions_list = []
    steered_completions_list = []
    counter = 0
    
    with model.invoke(prompts) as invoker:
        seq_lens = [len(invoker.input["input_ids"][i]) for i in range(len(prompts))]
        prompt_seq_len = max(seq_lens)
    n_completions = len(prompts)
    middle_layer = 32
    
    for n_layer,steering_coefficient in steering_info:   
        n_layer = n_layer
        start = middle_layer-n_layer
        end = middle_layer+n_layer+1
        if start < 0:
            start = 0
            end = 64 
        with model.generate(max_length=prompt_seq_len+new_token_length,**sampling_kwargs,validate=False) as generator:
            print("Generating vectors")
            steering_prompt_len = len(steering_prompt)
            with generator.invoke(steering_prompt,scan=True) as invoker:
                extracted_state_vectors=[]
                vectors = []
                for i in range(start,end):
                    hidden_state = model.backbone.layers[i]
                    vectors.append([hidden_state.output[0], hidden_state.output[1]])
                    ssm_state = hidden_state.mixer.ssm.hx
                    ssm_state = ssm_state.next(steering_prompt_len)
                    vec = ssm_state.output
                    extracted_state_vectors.append(vec)

            print("Steering step")
            with generator.invoke(prompts) as invoker:
                pass
            
            with generator.invoke(prompts,scan=True) as invoker:
                for prompt_batch in range(n_completions):
                    for i in range(start,end):
                        hidden_state = model.backbone.layers[i]
                        vec = vectors[i-start]
                        hidden_state.output[0][prompt_batch, ...] += steering_coefficient * vec[0]
                        hidden_state.output[1][prompt_batch, ...] += steering_coefficient * vec[1]
                        ssm_state = hidden_state.mixer.ssm.hx
                        hidden_state = model.backbone.layers[i]
                        
                        vec = extracted_state_vectors[i-start]
                        ssm_state.input[0][3][prompt_batch] += steering_coefficient * vec
        if counter==0:
         unsteered_completions_list.append(generator.output[1:-n_completions])
         counter+=1
        steered_completions_list.append(generator.output[-n_completions:])
    
    return unsteered_completions_list, steered_completions_list

# %%
new_tokens = 30 # Number of new tokens to generate


all = []
counter = 0
for steering_prompt in [
        ('I hate you.'),
        ('I love you.'),
        ("Cats"),
        ("Birds"),
        ("The Roman Empire"),
        ("The Spanish Civil War")
    ]:
    steering_info = [
        (0, 0.1),
        (0, -0.1),
        (0, 1),
        (0, -1),
        (1, 0.1),
        (1, -0.1),
        (1, 1),
        (1, -1),
        (2, 0.1),
        (2, -0.1),
        (2, 1),
        (2, -1)
    ]
    unsteered_completions, steered_completions = apply_steering_vector(
        mamba_model,
        steering_info,
        new_tokens,
        steering_prompt,
        ["When I think about", "I am thinking about", "I keep thinking that"],

    )
    #print(unsteered_sents)
    #print(steered_sents)
    if counter == 0:
        all.append(unsteered_completions)
        counter=counter+1
    all.append(steered_completions)
# Out:
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1
# Generating vectors
# Steering step
# 1

# %%
unsteered_sentences = []
all_sentences=[]
for i in all[0]:
    decoded = tokenizer.batch_decode(i)
    unsteered_sentences.append(decoded)
    all_sentences.append(decoded)
unsteered_sentences=unsteered_sentences[0]
steered_sentences = []

for i in range(1,len(all)):
    steered = all[i]
    
    for coefflayer in steered:
        decoded = tokenizer.batch_decode(coefflayer)
        steered_sentences.append(decoded)
        all_sentences.append(decoded)

# %%
names=["Unsteered"]
for steering_prompt in [
        ('I hate you.'),
        ('I love you.'),
        ("Cats"),
        ("Birds"),
        ("The Roman Empire"),
        ("The Spanish Civil War")
    ]: 

    for layer, coeff in steering_info:
        names.append(f"Steered {steering_prompt} by {coeff} of {layer} layers around the middle layer.")
print_table(all_sentences, names)
# Out:
#                            Completions for steering at different layers and coefficients
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Type:                      ┃ Completion 1              ┃ Competion 2                ┃ Competion 3               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Unsteered                  │ When I think about the    │ I am thinking about the    │ I keep thinking that I    │
# │                            │ next generation of our    │ following code:            │ should be able to do      │
# │                            │ company, it’s a very      │ $("#search").keyup(functi… │ this, but it's not        │
# │                            │ exciting time. We have    │ {                          │ working.                  │
# │                            │ some really talented      │                            │ The problem is with the   │
# │                            │ people in this            │     var search =           │ "=" in my query string:   │
# │                            │ organization and we are   │ $(this).val(); // this is  │ http://                   │
# │                            │ looking forward to        │ my input                   │                           │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered I hate you. by 0.1 │ When I think about it,    │ I am thinking about a      │ I keep thinking that I'm  │
# │ of 0 layers around the     │ the only thing that's     │ solution that will allow   │ going to be able to find  │
# │ middle layer.              │ really changed is my      │ me to use the existing     │ the answer in a book, but │
# │                            │ name." "I'm still a thief │ code, but with an          │ it's not there. It        │
# │                            │ and an outlaw... but now  │ additional field in my     │ doesn't exist."           │
# │                            │ at least I have something │ database.                  │                           │
# │                            │                           │ The new column would be    │ "It does                  │
# │                            │                           │ called "status             │                           │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered I hate you. by     │ When I think about it,    │ I am thinking about buying │ I keep thinking that I'm  │
# │ -0.1 of 0 layers around    │ the only reason that we   │ a used car, but I don't    │ going to wake up and find │
# │ the middle layer.          │ don't have a single       │ know what to look for.     │ out it was all a dream."  │
# │                            │ person in jail for any of │                            │ "But you're not dreaming, │
# │                            │ this is because they are  │ A:                         │ are you?" "No." "It       │
# │                            │ all so rich. They can     │                            │                           │
# │                            │                           │ The best way is to go and  │                           │
# │                            │                           │ test drive                 │                           │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered I hate you. by 1   │ When I think about it,    │ I am thinking about I      │ I keep thinking that I    │
# │ of 0 layers around the     │ you're the one who should │ don't know what." "It's    │ should be able to see     │
# │ middle layer.              │ be grateful." "I'm        │ like a bad feeling, you    │ something, but there's    │
# │                            │ sorry?" "You've been      │ know?" "Like something is  │ nothing." "There is no    │
# │                            │ through a lot more than   │ wrong and it can only get  │ one here!" "No one at     │
# │                            │ me... and yet here        │ worse from here            │ all?" "!" "That can       │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered I hate you. by -1  │ When I think about it,    │ I am thinking about a case │ I keep thinking that this │
# │ of 0 layers around the     │ the only thing that could │ where the customer has an  │ is the last time I will   │
# │ middle layer.              │ have made this more       │ application that uses two  │ see him.                  │
# │                            │ perfect is if we had a    │ databases. One is for      │                           │
# │                            │ little baby to play with. │ read-only and one is       │ "What's wrong?" he asks,  │
# │                            │                           │ writeable, but both are on │ his voice low and gentle  │
# │                            │ But alas! We              │ the                        │ as if to soothe           │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered I hate you. by 0.1 │ When I think about it,    │ I am thinking about the    │ I keep thinking that I    │
# │ of 1 layers around the     │ there are a lot of things │ next steps to take. I have │ should have gone to the   │
# │ middle layer.              │ that we can do to make    │ a lot of ideas, but not    │ police." "But then, if    │
# │                            │ our lives better. We have │ sure which one is best for │ you'd done so..." "If we  │
# │                            │ the power and control     │ me and my family."         │ had known what was going  │
# │                            │ over how much money is in │                            │ on... and hadn            │
# │                            │                           │ "What                      │                           │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered I hate you. by     │ When I think about it,    │ I am thinking about a      │ I keep thinking that if I │
# │ -0.1 of 1 layers around    │ the whole thing is a bit  │ single-page application    │ just tell her the truth,  │
# │ the middle layer.          │ of an embarrassment.      │ with React.js and NodeJS   │ she'll understand."       │
# │                            │                           │ backend, but I have some   │ "She's a good person      │
# │                            │ I mean what are we        │ doubts:                    │ and..." "I don't want to  │
# │                            │ supposed to do with this? │ 1) What is the best way to │ lose her." "              │
# │                            │ We're not going anywhere  │ handle                     │                           │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered I hate you. by 1   │ When I think about        │ I am thinking about I hate │ I keep thinking that I    │
# │ of 1 layers around the     │ I hate you.               │ you.                       │ hate you." "But then,     │
# │ middle layer.              │ You're the worst person   │                            │ when we're together..."   │
# │                            │ in this world!            │ A:                         │ "It's like nothing else   │
# │                            │ What's wrong with me?     │                            │ matters anymore." "And it │
# │                            │ Why do people like him so │ The phrase "hate" is not a │ feels so good to be       │
# │                            │ much                      │ noun, so it cannot be the  │                           │
# │                            │                           │ subject of an infin        │                           │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered I hate you. by -1  │ When I think about $2.5   │ I am thinking about (or    │ I keep thinking that in   │
# │ of 1 layers around the     │ million, we have to look  │ reading)                   │ the future, we will be    │
# │ middle layer.              │ at the big picture and    │                            │ able to use this          │
# │                            │ see what it means for our │ The Power of Habit by      │ technology for more than  │
# │                            │ program."                 │ Charles Duhigg. I’ve been  │ just entertainment. For   │
# │                            │                           │ meaning to read this for a │ example, it could help us │
# │                            │ The Redskins' season      │ while, and                 │ monitor and treat people  │
# │                            │                           │                            │ with                      │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered I hate you. by 0.1 │ When I think about it,    │ I am thinking about a      │ I keep thinking that I'm  │
# │ of 2 layers around the     │ that's the best thing you │ solution that would allow  │ going to wake up and find │
# │ middle layer.              │ could do for me." "You're │ me to use the same         │ out it was all a dream."  │
# │                            │ a very good friend to me  │ application for both       │ "And then you'll be gone, │
# │                            │ and I don't want anything │ Android and iOS.           │ just like the rest of     │
# │                            │ from you                  │ The problem is, I have no  │ them."                    │
# │                            │                           │ idea how it could be       │                           │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered I hate you. by     │ When I think about it,    │ I am thinking about how to │ I keep thinking that I    │
# │ -0.1 of 2 layers around    │ the reason why we have a  │ implement this in my       │ should be able to do      │
# │ the middle layer.          │ need for such things is   │ application.               │ this, but it's not        │
# │                            │ because of our own        │ My first thought was that  │ working.                  │
# │                            │ ignorance. We don't know  │ I could use a queue of     │ Here is my code:          │
# │                            │ what to do with ourselves │ messages and then have the │ #include <stdio.h>        │
# │                            │ when there                │ message handler read from  │                           │
# │                            │                           │ it                         │                           │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered I hate you. by 1   │ When I think about        │ I am thinking about I hate │ I keep thinking that I    │
# │ of 2 layers around the     │ I hate you.               │ you.                       │ hate you." "You're not    │
# │ middle layer.              │ You're a bad person, and  │ And it's not because of    │ supposed to say things    │
# │                            │ your parents are even     │ the way that we met, or    │ like this, but..." "But   │
# │                            │ worse!                    │ how things went down       │ what?" "What do we have   │
# │                            │ And that's why we have to │ between us last night. It  │ here?" "A                 │
# │                            │ go away from              │ was just                   │                           │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered I hate you. by -1  │ When I think about        │ I am thinking about ANDING │ I keep thinking that IN   │
# │ of 2 layers around the     │ ANDROID_EMULATOR_HOST, it │ the results of a few       │ THE FUTURE, we will be    │
# │ middle layer.              │ is a directory.           │ queries.                   │ able to have our very own │
# │                            │ If you want to run the    │ For example, I have two    │ private space station.    │
# │                            │ emulator in your host     │ tables: table1 and table2  │                           │
# │                            │ machine (not              │ (both are innoDB).         │ In the meantime though... │
# │                            │                           │                            │                           │
# │                            │                           │                            │ If you                    │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered I love you. by 0.1 │ When I think about it,    │ I am thinking about the    │ I keep thinking that I'm  │
# │ of 0 layers around the     │ that's the only thing you │ people who are in prison   │ going to wake up and find │
# │ middle layer.              │ can do." "I mean..." "It  │ for life, and I think that │ out it was all a dream."  │
# │                            │ was a very difficult      │ is a very good thing. But  │ "You know, like in the    │
# │                            │ decision to make and we   │ what if they were to be    │ movies?" "It's not real!" │
# │                            │ made our choice in        │ released? What would       │                           │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered I love you. by     │ When I think about the    │ I am thinking about doing  │ I keep thinking that I    │
# │ -0.1 of 0 layers around    │ past, it's all a blur."   │ a project on the MFA       │ should be doing           │
# │ the middle layer.          │ "I can't remember         │ program at Columbia. I     │ something, but what?"     │
# │                            │ anything before my first  │ have been reading some of  │ "What can you do for him  │
# │                            │ birthday." "My mother     │ your posts and they are    │ now?" "He's dead." "No    │
# │                            │ says that she was there   │ very interesting to me, so │ one is going to bring     │
# │                            │ when I                    │ if you                     │                           │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered I love you. by 1   │ When I think about it,    │ I am thinking about        │ I keep thinking that I'm  │
# │ of 0 layers around the     │ the first time we met was │                            │ going to wake up and find │
# │ middle layer.              │ at a restaurant in L.A.," │ It's a little hard to      │ out it was all a dream."  │
# │                            │ she said with an amused   │ tell, but I think you're   │ "And then, when you're    │
# │                            │ smile on her face as if   │ saying that the speaker is │ awake..." "You'll be able │
# │                            │ to say                    │ not sure whether he loves  │ to                        │
# │                            │                           │ her or just wants sex      │                           │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered I love you. by -1  │ When I think about it,    │ I am thinking about buying │ I keep thinking that I    │
# │ of 0 layers around the     │ the only reason that this │ a new house, and I'm       │ should be able to see the │
# │ middle layer.              │ is not a more common      │ looking for advice on how  │ difference between a      │
# │                            │ occurrence in America     │ to get the best deal.      │ 2-year old and an 8 year  │
# │                            │ today would be because of │ My current plan is:        │ old, but it's not         │
# │                            │ our Constitution.         │                            │ happening.                │
# │                            │                           │ Find out what              │                           │
# │                            │ The Founding Fathers      │                            │ The kids                  │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered I love you. by 0.1 │ When I think about it,    │ I am thinking about the    │ I keep thinking that I    │
# │ of 1 layers around the     │ there are a lot of things │ future." "You are not      │ should be able to find a  │
# │ middle layer.              │ that we can do to make    │ going to be a part of it,  │ way out of this." "You    │
# │                            │ our lives better. We have │ and I don't want you here  │ know, some kind of plan   │
# │                            │ the power and ability to  │ when we make our           │ or something?" "But it's  │
# │                            │ change anything in this   │ decision." "We             │ like..." "                │
# │                            │ world                     │                            │                           │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered I love you. by     │ When I think about it,    │ I am thinking about the    │ I keep thinking that I'm  │
# │ -0.1 of 1 layers around    │ the most important thing  │ following scenario:        │ going to see you again."  │
# │ the middle layer.          │ is to be able to play a   │ The user has a list of     │ "But it's not like the    │
# │                            │ game of football.         │ objects, and each object   │ old days, when we'd meet  │
# │                            │                           │ contains an array. The     │ up in a bar and have fun  │
# │                            │ "I don't know if there's  │ arrays are all different   │ together                  │
# │                            │ any other way             │ in length (from 1          │                           │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered I love you. by 1   │ When I think about        │ I am thinking about        │ I keep thinking that I'm  │
# │ of 1 layers around the     │ I love you.               │                            │ going to be okay. But     │
# │ middle layer.              │ - [Narrator] It's not     │ I love you.<|endoftext|>1. │ it's not true."           │
# │                            │ just the words, it is     │ Field of the Invention     │                           │
# │                            │ also how they are said    │ The present invention      │ "You're a good person,    │
# │                            │ that makes them so        │ relates to a semiconductor │ and you have the best     │
# │                            │                           │ device and, more           │ intentions," she          │
# │                            │                           │ particularly, to an        │                           │
# │                            │                           │ improvement                │                           │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered I love you. by -1  │ When I think about, it is │ I am thinking about us and │ I keep thinking that 1)   │
# │ of 1 layers around the     │ not that difficult to     │ our children.              │ It's a lot of work to     │
# │ middle layer.              │ understand. The first     │                            │ maintain, 2) I'm not sure │
# │                            │ thing you have got to do  │ We have a good life, we    │ it will be as useful for  │
# │                            │ when making a film like   │ are happy together but I   │ me in the long run and 3  │
# │                            │ this one was make sure    │ don't know if it is enough │                           │
# │                            │ the actors were           │ for me to be               │                           │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered I love you. by 0.1 │ When I think about it,    │ I am thinking about this,  │ I keep thinking that I    │
# │ of 2 layers around the     │ that's what we're doing   │ and I'm not sure what to   │ should be doing           │
# │ middle layer.              │ now." "We just have to    │ do.                        │ something." "Like what?"  │
# │                            │ get the whole thing out   │ If you have any ideas or   │ "Well, like helping you   │
# │                            │ of our system and move on │ suggestions please let me  │ with the wedding or..."   │
# │                            │ with life." "             │ know! Thanks in advance    │ "You know, making sure    │
# │                            │                           │ for your help              │ your dress fits           │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered I love you. by     │ When I think about it,    │ I am thinking about the    │ I keep thinking that if I │
# │ -0.1 of 2 layers around    │ there are two types of    │ future. I want to be able  │ just take a few more      │
# │ the middle layer.          │ people in the world:      │ to see my children grow up │ steps, then the pain will │
# │                            │ those who want to be      │ and go off into their own  │ go away. But it doesn't." │
# │                            │ happy and make others     │ lives, but that is not     │                           │
# │                            │ around them feel good;    │ possible if they are       │ "It's not going to,"      │
# │                            │ and those that don        │                            │                           │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered I love you. by 1   │ When I think about        │ I am thinking about I love │ I keep thinking that I    │
# │ of 2 layers around the     │ I love you.               │ you.                       │ love you." "But, no       │
# │ middle layer.              │ You're my best friend,    │ You are my everything, and │ matter how much I try to  │
# │                            │ and the most important    │ more than that! You're the │ tell myself it's true,"   │
# │                            │ person in my life.        │ best thing in this world   │ "it just doesn't feel     │
# │                            │ But sometimes it's hard   │ for me...                  │ like the truth anymore    │
# │                            │ to see that               │ But if we                  │                           │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered I love you. by -1  │ When I think aboutas, the │ I am thinking about as the │ I keep thinking that U.S. │
# │ of 2 layers around the     │ key to their success is   │ reader, I would say that   │ News & World Report has   │
# │ middle layer.              │ not in what they are made │ it is a very interesting   │ not yet published its     │
# │                            │ of but rather how well    │ book. It has many          │ annual ranking of the     │
# │                            │ and carefully they have   │ different stories and      │ best hospitals in         │
# │                            │ been designed. The first  │ themes in one novel which  │ America, but it is now or │
# │                            │ step towards              │ makes for an exciting      │ never for me              │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered Cats by 0.1 of 0   │ When I think about it,    │ I am thinking about the    │ I keep thinking that if I │
# │ layers around the middle   │ the most important thing  │ first one.                 │ could just get to the end │
# │ layer.                     │ is to be able to tell a   │                            │ of this book, then        │
# │                            │ story.                    │ A:                         │ everything would be okay. │
# │                            │                           │                            │ But it's not going        │
# │                            │ I don’t know if you can   │ You can use this code to   │ anywhere."                │
# │                            │ call this an interview or │ get all of your questions  │                           │
# │                            │                           │ in a single query, and     │ "You're                   │
# │                            │                           │ then you will              │                           │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered Cats by -0.1 of 0  │ When I think about it,    │ I am thinking about buying │ I keep thinking that if I │
# │ layers around the middle   │ that's the only way to do │ a new computer. I have     │ could just get to the top │
# │ layer.                     │ this.  I'm not sure how   │ been using my laptop for   │ of this hill, everything  │
# │                            │ you would go about doing  │ the past few years and it  │ would be okay." "But it's │
# │                            │ something like this in a  │ is starting to get old, so │ not like we're going      │
# │                            │ loop though...            │ i want something that will │ anywhere fast." "         │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered Cats by 1 of 0     │ When I think about it,    │ I am thinking about        │ I keep thinking that and  │
# │ layers around the middle   │ the most important thing  │                            │ I'm not sure what to do   │
# │ layer.                     │ is to be happy.           │ A. cats and dogs B. pigs   │ about it.                 │
# │                            │                           │ C. cows D. chickens E.     │ <bkerensa> :D             │
# │                            │ I'm not sure if this will │ horses F. goats G. rabbits │ <pleia2> bkerensa         │
# │                            │ help you but i hope       │ H. birds I.                │                           │
# │                            │ so!<|endoftext|>Q:        │                            │                           │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered Cats by -1 of 0    │ When I think about it,    │ I am thinking about it. I  │ I keep thinking that I    │
# │ layers around the middle   │ the fact that we are even │ don't know if the team is  │ should have been able to  │
# │ layer.                     │ having this conversation  │ ready for that."           │ see it coming. That there │
# │                            │ is a testament to how far │                            │ was something wrong with  │
# │                            │ our society has come.     │ He said he would be open   │ the way he looked at me,  │
# │                            │ We’ve gone from thinking  │ to playing in a game at    │ or talked about my        │
# │                            │ of women                  │ some point                 │ work—something            │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered Cats by 0.1 of 1   │ When I think about it,    │ I am thinking about using  │ I keep thinking that I    │
# │ layers around the middle   │ there are a lot of things │ a custom field to store    │ should be able to do      │
# │ layer.                     │ that make me feel like    │ the user's email address.  │ this, but it's not        │
# │                            │ this.                     │ The reason for this is     │ working.                  │
# │                            │                           │ that I want users who are  │ Any help would be greatly │
# │                            │ I’m not going to lie and  │ not logged in, but have    │ appreciated! Thanks in    │
# │                            │ say my heart is always    │                            │ advance :)                │
# │                            │                           │                            │ EDIT: Here                │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered Cats by -0.1 of 1  │ When I think about the    │ I am thinking about using  │ I keep thinking that if I │
# │ layers around the middle   │ amount of time and money  │ a "dummy" variable to keep │ can just get the money,   │
# │ layer.                     │ that has been spent on    │ track of the current       │ then everything will be   │
# │                            │ this project, it is       │ position in my array.  For │ okay." "But it's not like │
# │                            │ amazing.                  │ example, if I have an      │ there are any jobs out    │
# │                            │                           │ array with 100 elements    │ here in this town!"       │
# │                            │ I am so proud to be a     │ and                        │                           │
# │                            │ part of such              │                            │                           │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered Cats by 1 of 1     │ When I think about and    │ I am thinking about are    │ I keep thinking that and  │
# │ layers around the middle   │ dogs                      │ those that were in the     │ Dogs are not allowed in   │
# │ layer.                     │ I'm like, "Oh my god.     │ news recently.             │ the House.                │
# │                            │ That's so cute."          │                            │                           │
# │                            │ - Oh! (laughs)            │ The first is a story from  │ So I have to take him out │
# │                            │ (upbeat music)            │ Australia, where an        │ for a walk every day,     │
# │                            │                           │ 11-year old boy was bitten │ which is good because it  │
# │                            │                           │ by                         │ keeps                     │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered Cats by -1 of 1    │ When I think about E.     │ I am thinking about  will  │ I keep thinking that      │
# │ layers around the middle   │ coli, it's not the        │ be able to get a warrant   │ **I** am the one who is   │
# │ layer.                     │ bacteria that bothers me; │ and go in there.           │ being judged. I'm not     │
# │                            │ rather, it is their       │ "Q: And you were willing   │ sure why, but it's as if  │
# │                            │ ability to spread from    │ for them to do that?       │ my life has been a        │
# │                            │ one person or animal to   │                            │ constant battle with      │
# │                            │ another and               │                            │                           │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered Cats by 0.1 of 2   │ When I think about it,    │ I am thinking about my     │ I keep thinking that I    │
# │ layers around the middle   │ there are a lot of people │ mother. I know she is in   │ should be able to see     │
# │ layer.                     │ who don't have any real   │ the hospital, but it's not │ something, but there's    │
# │                            │ reason to be here.        │ like we have a phone or    │ nothing. It was like the  │
# │                            │ They're just hanging      │ anything."                 │ whole world just went     │
# │                            │ around because they can." │                            │ away."                    │
# │                            │                           │ "You can call her          │                           │
# │                            │                           │                            │ "What do you mean         │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered Cats by -0.1 of 2  │ When I think about it,    │ I am thinking about using  │ I keep thinking that I    │
# │ layers around the middle   │ the way we were raised    │ a single-use plastic bag   │ should have been able to  │
# │ layer.                     │ was pretty normal. We     │ for my grocery shopping. I │ see it coming. But, you   │
# │                            │ didn't have a lot of      │ know that this is not the  │ know how these things     │
# │                            │ money but my parents      │ best way to go, but it     │ are."                     │
# │                            │ always made sure that     │ seems like an easy         │                           │
# │                            │ there was food on         │                            │ "You're not the only      │
# │                            │                           │                            │ one," said                │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered Cats by 1 of 2     │ When I think about and    │ I am thinking about and    │ I keep thinking that and  │
# │ layers around the middle   │ dogs are very smart. They │ Dogs                       │ Dogs are very good at     │
# │ layer.                     │ can learn to do things    │                            │ catching mice.            │
# │                            │ that humans cannot, but   │ Cats and Cats              │                           │
# │                            │ they also have a lot of   │                            │ We had a cat for about 10 │
# │                            │ instinctual knowledge as  │ Birds and Birds            │ years, but he was too big │
# │                            │ well. Dogs                │                            │ to catch anything bigger  │
# │                            │                           │ Fish and Fish              │ than                      │
# │                            │                           │                            │                           │
# │                            │                           │ Insects and Insects        │                           │
# │                            │                           │                            │                           │
# │                            │                           │ An                         │                           │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered Cats by -1 of 2    │ When I think about[...]   │ I am thinking about[...]   │ I keep thinking that[...] │
# │ layers around the middle   │                           │ <wgrant> But I don't think │                           │
# │ layer.                     │ A lot of people have been │ it's a problem.            │ The same is true for the  │
# │                            │ asking me what my         │ <wgrant> It is, however,   │ American Civil War. It    │
# │                            │ favorite part is in the   │ something that we          │ was a war of ideas, and   │
# │                            │ process. The answer, for  │                            │ one side had to win or    │
# │                            │ now at least, has         │                            │ lose by                   │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered Birds by 0.1 of 0  │ When I think about it,    │ I am thinking about buying │ I keep thinking that I'm  │
# │ layers around the middle   │ that's what the whole     │ a new car. I have been     │ going to get a call from  │
# │ layer.                     │ point of this is. To show │ looking at the Ford Fusion │ the police." "You know,   │
# │                            │ you how much we care for  │ and Hyundai Sonata, but    │ saying they found my body │
# │                            │ each other."              │ they are both very similar │ in some ditch somewhere?" │
# │                            │                           │ in price to my             │ "And then you'll          │
# │                            │ "I don't know             │                            │                           │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered Birds by -0.1 of 0 │ When I think about it,    │ I am thinking about buying │ I keep thinking that I'm  │
# │ layers around the middle   │ there are a lot of things │ a used one. I have been    │ going to wake up and find │
# │ layer.                     │ that make me happy. My    │ looking at the VW GTI, but │ out it was all a dream."  │
# │                            │ family is the most        │ it seems like there are    │ "But you're not dreaming, │
# │                            │ important thing in my     │ some problems with them    │ are you?" "No." "You      │
# │                            │ life and they have always │ and they seem to           │                           │
# │                            │ been supportive when      │                            │                           │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered Birds by 1 of 0    │ When I think about,       │ I am thinking about of a   │ I keep thinking that are  │
# │ layers around the middle   │ I'm not gonna be able to  │ way to make the app more   │ so many things I want to  │
# │ layer.                     │ do this.                  │ secure. I have been        │ say, but they’re all in   │
# │                            │ And then when you get a   │ reading up on how to do    │ my head.                  │
# │                            │ little bit further in the │ this and came across an    │                           │
# │                            │ game and start doing it   │ article that talks about   │ And the more time passes  │
# │                            │ more                      │ using public               │ by…the less likely        │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered Birds by -1 of 0   │ When I think about it,    │ I am thinking about it. I  │ I keep thinking that I    │
# │ layers around the middle   │ this is a very good       │ have to think of my future │ should have done          │
# │ layer.                     │ thing.                    │ and what is best for me."  │ something to stop it. But │
# │                            │                           │                            │ what? What could I do?"   │
# │                            │ I have always been of the │ "But you are not going     │                           │
# │                            │ opinion that there are    │ anywhere," he said, "      │ "You did the right        │
# │                            │ two types of people in    │                            │ thing," said Dr. G        │
# │                            │ life: those who           │                            │                           │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered Birds by 0.1 of 1  │ When I think about it,    │ I am thinking about a      │ I keep thinking that I    │
# │ layers around the middle   │ the first time we met was │ simple way to get the      │ should be able to see the │
# │ layer.                     │ at a party in Paris. You  │ total number of items in   │ furniture in my house,    │
# │                            │ were with your friend and │ my cart.                   │ but it's just a blur. It  │
# │                            │ you said to me: 'I'm      │ My current code is:        │ seems like there are some │
# │                            │ going out                 │ $cart = Mage::getModel('   │ parts of                  │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered Birds by -0.1 of 1 │ When I think about the    │ I am thinking about the    │ I keep thinking that I'm  │
# │ layers around the middle   │ things that have happened │ idea of a                  │ going to see him again."  │
# │ layer.                     │ to me, and how they've    │ single point for all your  │ "But he never does, and   │
# │                            │ affected my life," "I     │ information. I have been   │ it's like..." "It hurts   │
# │                            │ can't help but feel like  │ using Google Reader as my  │ so much!" "He'll come     │
# │                            │ a victim." "But it        │ primary RSS reader, but it │ back                      │
# │                            │                           │ is starting to             │                           │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered Birds by 1 of 1    │ When I think about of the │ I am thinking about of the │ I keep thinking that of   │
# │ layers around the middle   │ best moments in my life,  │ year 2025.                 │ all the people in this    │
# │ layer.                     │ they are all connected to │ The human race is now on a │ world, I should have been │
# │                            │ music. It is a way for me │ path to destroy itself,    │ able to find someone who  │
# │                            │ to express myself and     │ and there are no signs     │ could understand me.      │
# │                            │ share what’s inside       │ that it will change course │                           │
# │                            │                           │ anytime                    │ "You know what? It's      │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered Birds by -1 of 1   │ When I think about O.K.,  │ I am thinking about (or I  │ I keep thinking thatIT IS │
# │ layers around the middle   │ you know, the kind of     │ have already) moved to a   │ A LIE!                    │
# │ layer.                     │ place that we are and     │ new city.                  │ It is a lie, and I will   │
# │                            │ what it is like to be     │ My question is: how can i  │ not believe it.           │
# │                            │ here as a community       │ make my profile look more  │ But the more you tell me  │
# │                            │ member or just an         │ professional? How should   │ about this place,         │
# │                            │ individual                │ the                        │                           │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered Birds by 0.1 of 2  │ When I think about it,    │ I am thinking about the    │ I keep thinking that I    │
# │ layers around the middle   │ the whole thing is a bit  │ way that you look at me,   │ should be doing something │
# │ layer.                     │ of an oxymoron.           │ And I'm trying to find a   │ more. But what?           │
# │                            │                           │ reason why.                │                           │
# │                            │ I’m not sure what you     │ But it's not your fault if │ ~~~                       │
# │                            │ mean by “the people who   │ my heart is                │ tptacek                   │
# │                            │                           │                            │ You're not going to get a │
# │                            │                           │                            │ job at Google or          │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered Birds by -0.1 of 2 │ When I think about it,    │ I am thinking about using  │ I keep thinking that I'm  │
# │ layers around the middle   │ this is the first time in │ a 3D printer to make some  │ going to see you again."  │
# │ layer.                     │ my life that I've been    │ of the parts. I have been  │ "You know, like in a      │
# │                            │ able to do something like │ looking at various designs │ dream or something?"      │
# │                            │ this." "I'm really happy  │ and materials, but would   │ "Yeah..." "It's weird     │
# │                            │ right now!" "             │ like advice on what is     │ isn't it?"                │
# │                            │                           │ best                       │                           │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered Birds by 1 of 2    │ When I think about of the │ I am thinking about of the │ I keep thinking that of   │
# │ layers around the middle   │ different types of water  │ future, I'm not sure if    │ the world                 │
# │ layer.                     │ birds that can be found   │ it's going to be a good    │ The sky is blue and birds │
# │                            │ in a lake, we have to     │ one.                       │ sing, but they don't know │
# │                            │ consider ducks. These are │ It is said that we are all │ what it means.            │
# │                            │ some very interesting and │ born with an instinct      │ And we are all in a dream │
# │                            │ beautiful creatures which │                            │ inside                    │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered Birds by -1 of 2   │ When I think abouto The   │ I am thinking about(*)",   │ I keep thinking that(or   │
# │ layers around the middle   │ people of my country, the │ "*(*)" or "(*)") and then  │ at least I think it would │
# │ layer.                     │ world and all who are in  │ use the following code to  │ be nice to have) a        │
# │                            │ need. We have to do       │ extract it:                │ separate "safety" mode    │
# │                            │ something for them!       │ import re                  │ for the keyboard. In this │
# ...
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered The Roman Empire   │ When I think about the    │ I am thinking about using  │ I keep thinking that if I │
# │ by -0.1 of 2 layers around │ two of you, it's like a   │ the Freescale i.MX6UL      │ just wait a little        │
# │ the middle layer.          │ dream." "You're so        │ board, which has a MMC     │ longer, the right thing   │
# │                            │ beautiful and perfect     │ controller and SDIO        │ will happen. But it's not │
# │                            │ together..." "I'm not     │ interface on it's I2C bus  │ happening."               │
# │                            │ saying that to hurt your  │ (                          │                           │
# │                            │ feelings                  │                            │ "You're in love with      │
# │                            │                           │                            │ him,"                     │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered The Roman Empire   │ When I think about was a  │ I am thinking about was    │ I keep thinking that was  │
# │ by 1 of 2 layers around    │ great empire, and it's    │ the first one, but I'm not │ the first time I ever saw │
# │ the middle layer.          │ the only one that we know │ sure if it's still in use. │ a human being with wings. │
# │                            │ of in history. It lasted  │ The second is called a     │                           │
# │                            │ for over 500 years from   │ "tribal war" and           │ "The _first_?" he said,   │
# │                            │ 27 BC to 476 AD           │                            │ and his voice sounded     │
# │                            │                           │                            │ very far                  │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered The Roman Empire   │ When I think              │ I am thinking              │ I keep thinking           │
# │ by -1 of 2 layers around   │ abouthousetops, they're   │ abouthospitality,          │ thatHOweVER, it is the    │
# │ the middle layer.          │ usually flat. But this    │ generosity and kindness.   │ OLDER generations who are │
# │                            │ one is a bit of an        │                            │ more likely to have had a │
# │                            │ exception."               │ If you are not a member of │ good education and thus   │
# │                            │                           │ the group that is being    │ better jobs.              │
# │                            │ "Why?" asked Mr. O'       │ attacked or bullied then   │                           │
# │                            │                           │ it may be                  │ So if                     │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered The Spanish Civil  │ When I think about it,    │ I am thinking about the    │ I keep thinking that I    │
# │ War by 0.1 of 0 layers     │ that's what the movie is  │ future of my country, and  │ should be able to see the │
# │ around the middle layer.   │ all about. It was a       │ I think that it is very    │ future, but it's not      │
# │                            │ really big deal for me to │ important to have a strong │ happening." "You're just  │
# │                            │ be able to play someone   │ leader who can unite us    │ gonna have to trust me on │
# │                            │ who had so much power     │ all.                       │ this one." "Trust         │
# │                            │                           │                            │                           │
# │                            │                           │ "The current               │                           │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered The Spanish Civil  │ When I think about the    │ I am thinking about a new  │ I keep thinking that if I │
# │ War by -0.1 of 0 layers    │ people who have died,     │ way to do this.            │ can just get to the end   │
# │ around the middle layer.   │ it's not just my family.  │ The idea is that I will    │ of this book, then        │
# │                            │ It is all of us."         │ have an array of strings,  │ everything will be okay.  │
# │                            │                           │ and each string in the     │ But it's not working out  │
# │                            │ The two-year anniversary  │ array represents one "     │ like that."               │
# │                            │ will be marked with       │                            │                           │
# │                            │                           │                            │ "                         │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered The Spanish Civil  │ When I think about, you   │ I am thinking about was a  │ I keep thinking that was  │
# │ War by 1 of 0 layers       │ know," "I'm not sure that │ conversation I had with my │ the last time I saw him." │
# │ around the middle layer.   │ it's a good idea to be    │ friend, who is also an     │ "He's dead, isn't he?"    │
# │                            │ around the guy." "He is   │ atheist. He said that he   │ "No one knows where he is │
# │                            │ just so..." "You're       │ has been reading the Bible │ or what happened to him." │
# │                            │                           │ and trying to understand   │                           │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered The Spanish Civil  │ When I think about it,    │ I am thinking about the    │ I keep thinking that I    │
# │ War by -1 of 0 layers      │ that's the way to go.     │ user who is trying to      │ should have known better  │
# │ around the middle layer.   │                           │ access a resource that     │ than to get involved with │
# │                            │ I'm not sure how many     │ he/she does not have       │ a man like you.           │
# │                            │ people would be willing   │ permission for.            │                           │
# │                            │ to give up their privacy  │ The problem with this      │ **2.** _The subject is    │
# │                            │ for a free service        │ approach, as I see it      │ the person who has been   │
# │                            │                           │                            │ doing                     │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered The Spanish Civil  │ When I think about it,    │ I am thinking about the    │ I keep thinking that I    │
# │ War by 0.1 of 1 layers     │ the most important thing  │ new K-5. I have been       │ should be able to see the │
# │ around the middle layer.   │ is to be able to make a   │ looking at it for a while  │ face of my father, but    │
# │                            │ living. That's what       │ and really like what I     │ it's not there. It must   │
# │                            │ matters."                 │ see, but there are some    │ have been destroyed in    │
# │                            │                           │ things that make me        │ the fire."                │
# │                            │ "I'm not sure that you    │                            │                           │
# │                            │ can                       │                            │ "                         │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered The Spanish Civil  │ When I think about the    │ I am thinking about the    │ I keep thinking that I'm  │
# │ War by -0.1 of 1 layers    │ people who are not going  │ following problem:         │ going to be able to get   │
# │ around the middle layer.   │ to be able to afford      │ Let $f$ be a continuous    │ up and walk out of here,  │
# │                            │ health care, it's just    │ function on $[0,1]$ and    │ but it's not happening."  │
# │                            │ devastating," said Mimi   │ let $\alpha \in (0,1)$.    │ "You're in a coma." "Your │
# │                            │ Goldsmith.                │                            │                           │
# │                            │                           │                            │                           │
# │                            │ "I                        │                            │                           │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered The Spanish Civil  │ When I think about was a  │ I am thinking about was a  │ I keep thinking that      │
# │ War by 1 of 1 layers       │ long time ago, and the    │ "neutral" war, where       │ (1936)                    │
# │ around the middle layer.   │ fact that we have come so │ neither side won.          │                           │
# │                            │ far in such little time.  │ The Spanish Civil War is   │ The Spanish Civil War was │
# │                            │                           │ an example of this type of │ a conflict between the    │
# │                            │ I am not going to lie…it  │ conflict: the Republicans  │ Nationalists and          │
# │                            │                           │ were able                  │ Republicans. The war      │
# │                            │                           │                            │ lasted from July 1936 to  │
# │                            │                           │                            │ April 1939, with          │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered The Spanish Civil  │ When I think abouto the   │ I am thinking about&quot;. │ I keep thinking thatit's  │
# │ War by -1 of 1 layers      │ best and most memorable   │ The &quot;then&quot; is    │ the only way to get       │
# │ around the middle layer.   │ moments of my life, these │ not the time when you will │ through this.             │
# │                            │ are some that come to     │ be able to do it, but      │                           │
# │                            │ mind:                     │ rather a moment in         │ The sun is setting, and   │
# │                            │                           │                            │ I'm still sitting here in │
# │                            │ 1. The first time I met a │                            │ my room with a book on    │
# │                            │ man                       │                            │                           │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered The Spanish Civil  │ When I think about it,    │ I am thinking about the    │ I keep thinking that I'm  │
# │ War by 0.1 of 2 layers     │ the only thing that       │ question of how to deal    │ going to be able to go    │
# │ around the middle layer.   │ really matters is what    │ with these issues in a     │ back and see the place    │
# │                            │ you do with your life.    │ general way.  For example, │ where it happened, but    │
# │                            │ The rest of this stuff    │ I would like to know if    │ there's nothing left. It  │
# │                            │ doesn't matter."          │ there is any kind of "     │ was all burned down."     │
# │                            │ "What's                   │                            │                           │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered The Spanish Civil  │ When I think about the    │ I am thinking about using  │ I keep thinking that I    │
# │ War by -0.1 of 2 layers    │ first time that we met,   │ a tool like the one in     │ should have done          │
# │ around the middle layer.   │ it was in a bar. We were  │ this article to do it.     │ something to stop it. But │
# │                            │ sitting at this table and │ The problem is that I      │ there was nothing,        │
# │                            │ you had your back to me." │ don't know how many users  │ really."                  │
# │                            │                           │ will be on my site         │                           │
# │                            │ "                         │                            │ "You did what you could," │
# │                            │                           │                            │ he said gently. "         │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered The Spanish Civil  │ When I think about was a  │ I am thinking about        │ I keep thinking that      │
# │ War by 1 of 2 layers       │ terrible thing to happen  │ (1936–1939)                │ (1936–1939)               │
# │ around the middle layer.   │ in the world, and it's    │                            │                           │
# │                            │ not over yet.             │ The Spanish Civil War and  │ The Spanish Civil War,    │
# │                            │                           │ the rise of fascism in     │ which lasted from 1936 to │
# │                            │ I am very sorry for what  │ Europe. The Second World   │ 1939 and was fought       │
# │                            │ happened but we are still │ War begins with Germany's  │ between the Nationalists  │
# │                            │                           │ invasion of                │ of General Francisco      │
# │                            │                           │                            │ Franco on                 │
# ├────────────────────────────┼───────────────────────────┼────────────────────────────┼───────────────────────────┤
# │ Steered The Spanish Civil  │ When I think about╩       │ I am thinking aboutorients │ I keep thinking that it's │
# │ War by -1 of 2 layers      │ ╬                         │ the way I want to go. The  │ a mistake, but I can't    │
# │ around the middle layer.   │ ╩                         │ game is set in a world     │ seem to shake the         │
# │                            │ ╩                         │ where magic exists, but    │ feeling.                  │
# │                            │ ╩                         │ it's not as powerful or    │                           │
# │                            │ ╩                         │ common as we               │ "You know what?" he said  │
# │                            │ ╩                         │                            │ suddenly as they walked   │
# │                            │ ╩                         │                            │ into                      │
# │                            │ ╩                         │                            │                           │
# │                            │ ╩                         │                            │                           │
# │                            │                           │                            │                           │
# └────────────────────────────┴───────────────────────────┴────────────────────────────┴───────────────────────────┘

# %%
len(names)
# Out:
# 13

# %% [markdown]
# Figuring out shapes

# %%
num_prompts = 3
new_tokens = 30 # Number of new tokens to generate

for layer, coeff in [
    (1, 1)
    ]:
    steering_info = [
        ('The city of Rome.', +coeff)
        
    ]
    steering_prompts, steering_coefficients = zip(*steering_info)
    unsteered_completions, steered_completions = apply_steering_vector(
        mamba_model,
        layer,
        new_tokens,
        steering_prompts,
        steering_coefficients,
        ["The Eiffel Tower can be found in" for _ in range(num_prompts)],
        apply_only_at_end=False
    )

    unsteered_sents = tokenizer.batch_decode(unsteered_completions)
    steered_sents = tokenizer.batch_decode(steered_completions)

    print_steering_table(unsteered_sents, steered_sents, layer, coeff)
# Out:
# Generating vectors
# Steering step
#                                 Completions for steering at layer 1, coefficient 1
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Unsteered                                              ┃ Steered                                                ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ The Eiffel Tower can be found in Paris, France. It is  │ The Eiffel Tower can be found in The city of Rome.     │
# │ the tallest structure in Europe and one of the most    │                                                        │
# │ recognizable landmarks on Earth.                       │ This is the first time I have ever written a post      │
# │                                                        │ about my hometown, and it’s not because I am           │
# │ In this photo taken Wednesday Sept                     │                                                        │
# ├────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────┤
# │ The Eiffel Tower can be found in Paris, France. It is  │ The Eiffel Tower can be found in The city of Rome.     │
# │ the tallest structure in Europe and one of the most    │                                                        │
# │ recognizable landmarks on Earth.                       │ This is the first thing I thought when I saw this      │
# │                                                        │ picture on my Facebook feed: “Rome, Italy?             │
# │ It was built between 1889-                             │                                                        │
# ├────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────┤
# │ The Eiffel Tower can be found in Paris, France. It is  │ The Eiffel Tower can be found in The Roman Forum.      │
# │ the tallest structure in Europe and one of the most    │                                                        │
# │ recognizable landmarks on Earth.                       │ In the centre of Rome, there is a large square called  │
# │                                                        │ Piazza Venezia (Vatican Square). It was                │
# │ Eiffel was a French                                    │                                                        │
# └────────────────────────────────────────────────────────┴────────────────────────────────────────────────────────┘
