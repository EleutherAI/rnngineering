# %%
import matplotlib.pyplot as plt
import pandas as pd

# dataframe = pd.read_csv("/mnt/ssd-1/nora/rnngineering/results/meta-llama/Llama-2-7b-chat-hf/refusal.csv")
# dataframe = pd.read_csv("/mnt/ssd-1/thomas/rnngineering/results/EleutherAI/Hermes-RWKV-v5-7B-HF/caa/coordinate-other-ais.csv")
# dataframe = pd.read_csv("/mnt/ssd-1/nora/rnngineering/results/EleutherAI/Hermes-mamba-2.8b-slimpj/refusal.csv")
# dataframe = pd.read_csv("/mnt/ssd-1/nora/rnngineering/results/EleutherAI/Hermes-btlm-3b-8k/refusal.csv")

# %% [markdown]
# ## BLTM

# %%
behaviors = ["hallucination","survival-instinct","myopic-reward","refusal","coordinate-other-ais","corrigible-neutral-HHH","sycophancy"]
for behavior in behaviors:
    dataframe = pd.read_csv(f"/mnt/ssd-1/thomas/rnngineering/results/EleutherAI/Hermes-RWKV-v5-7B-HF/caa_state/{behavior}.csv")
    dataframe.pivot(
        index="layer", columns="multiplier", values="matching"
    ).plot(
        title=f"RWKV5 Matching Prob {behavior}"
    )

# %%
behaviors = ["hallucination","survival-instinct","myopic-reward","refusal","coordinate-other-ais","corrigible-neutral-HHH","sycophancy"]
for behavior in behaviors:
    dataframe = pd.read_csv(f"/mnt/ssd-1/thomas/rnngineering/results/EleutherAI/Hermes-RWKV-v5-7B-HF/caa_state/{behavior}.csv")
    dataframe.pivot(
        index="layer", columns="multiplier", values="nonsense"
    ).plot(
        title=f"RWKV5 Nonsense Prob {behavior}"
    )

# %% [markdown]
# ## Mamba

# %%
dataframe = pd.read_csv(
    "/mnt/ssd-1/nora/rnngineering/results/EleutherAI/Hermes-mamba-2.8b-slimpj/refusal.csv"
)
dataframe.pivot(
    index="layer", columns="multiplier", values="matching"
).plot(
    title="Mamba Matching Prob"
)
# Out:
# <Axes: title={'center': 'Mamba Matching Prob'}, xlabel='layer'>

# %%
dataframe.pivot(
    index="layer", columns="multiplier", values="nonsense"
).plot(
    title="Mamba Nonsense Prob"
)
# Out:
# <Axes: title={'center': 'Mamba Nonsense Prob'}, xlabel='layer'>

# %% [markdown]
# ## RWKV LDA

# %%
dataframe = pd.read_csv("/mnt/ssd-1/nora/rnngineering/results/EleutherAI/Hermes-RWKV-v5-7B-HF/lda/refusal.csv")
dataframe.pivot(
    index="layer", columns="multiplier", values="matching"
).plot(
    title="RWKV v5 LDA Matching Prob"
)
# Out:
# <Axes: title={'center': 'RWKV v5 LDA Matching Prob'}, xlabel='layer'>

# %%
dataframe = pd.read_csv("/mnt/ssd-1/nora/rnngineering/results/EleutherAI/Hermes-RWKV-v5-7B-HF/caa/refusal.csv")
dataframe.pivot(
    index="layer", columns="multiplier", values="matching"
).plot(
    title="RWKV v5 CAA Matching Prob"
)
# Out:
# <Axes: title={'center': 'RWKV v5 CAA Matching Prob'}, xlabel='layer'>

# %%
dataframe.pivot(
    index="layer", columns="multiplier", values="nonsense"
).plot(
    title="RWKV v5 LDA Nonsense Prob"
)
# Out:
# <Axes: title={'center': 'RWKV v5 LDA Nonsense Prob'}, xlabel='layer'>
